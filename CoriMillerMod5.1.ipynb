# %%
## Cori Miller Module 5 - Part 1

# %%
import pandas as pd

# %%
grades = pd.Series([87, 100, 94])

# %%
grades[0]
# Out:
# 87

# %%
grades.count()
# Out:
# 3

# %%
grades.mean()
# Out:
# 93.66666666666667

# %%
grades.min()
# Out:
# 87

# %%
grades.max()
# Out:
# 100

# %%
grades.std()
# Out:
# 6.506407098647712

# %%
grades.describe()
# Out:
# count      3.000000
# mean      93.666667
# std        6.506407
# min       87.000000
# 25%       90.500000
# 50%       94.000000
# 75%       97.000000
# max      100.000000
# dtype: float64

# %%
grades = pd.Series({'Wally': 87, 'Eva': 100, 'Sam': 94})

# %%
grades
# Out:
# Wally     87
# Eva      100
# Sam       94
# dtype: int64

# %%
grades ['Eva']
# Out:
# 100

# %%
grades.Wally
# Out:
# 87

# %%
grades.values
# Out:
# array([ 87, 100,  94], dtype=int64)
